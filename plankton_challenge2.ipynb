# %% [markdown]
# <h3>Algorithmic Machine Learning Challenge</h3>
# <h1>Plankton Image Classification</h1>
# <hr style="height:2px;border:none;color:#333;background-color:#333;"/>

# %% [markdown]
# Plankton comprises all the organisms freely drifting with ocean currents. These life forms are a critically important piece of oceanic ecosystems, accounting for more than half the primary production on earth and nearly half the total carbon fixed in the global carbon cycle. They also form the foundation of aquatic food webs, including those of large, commercially important fisheries. Loss of plankton populations could result in ecological upheaval as well as negative societal impacts, particularly in indigenous cultures and the developing world. Plankton’s global significance makes their population levels an ideal measure of the health of the world’s oceans and ecosystems.
#
# Traditional methods for measuring and monitoring plankton populations are time consuming and cannot scale to the granularity or scope necessary for large-scale studies. Improved approaches are needed. One such approach is through the use of underwater imagery sensors.
#
# In this challenge, which was prepared in cooperation with the Laboratoire d’Océanographie de Villefranche, jointly run by Sorbonne Université and CNRS, plankton images were acquired in the bay of Villefranche, weekly since 2013 and manually engineered features were computed on each imaged object.
#
# This challenge aims at developing solid approaches to plankton image classification. We will compare methods based on carefully (but manually) engineered features, with “Deep Learning” methods in which features will be learned from image data alone.
#
# The purpose of this challenge is for you to learn about the commonly used paradigms when working with computer vision problems. This means you can choose one of the following paths:
#
# - Work directly with the provided images, e.g. using a (convolutional) neural network
# - Work with the supplied features extracted from the images (*native* or *skimage* or both of them)
# - Extract your own features from the provided images using a technique of your choice
#
# You will find a detailed description about the image data and the features at the end of this text.
# In any case, the choice of the classifier that you decide to work with strongly depends on the choice of features.
#
# Please bear in mind that the purpose of this challenge is not simply to find the best-performing model that was released on e.g. Kaggle for a similar problem. You should rather make sure to understand the dificulties that come with this computer vision task. Moreover, you should be able to justify your choice of features/model and be able to explain its advantages and disadvantages for the task.

# %% [markdown]
# # Overview
# <hr style="height:1px;border:none;color:#333;background-color:#333;" />

# %% [markdown]
# Beyond simply producing a well-performing model for making predictions, in this challenge we would like you to start developing your skills as a machine learning scientist.
# In this regard, your notebook should be structured in such a way as to explore the five following tasks that are expected to be carried out whenever undertaking such a project.
# The description below each aspect should serve as a guide for your work, but you are strongly encouraged to also explore alternative options and directions.
# Thinking outside the box will always be rewarded in these challenges.

# %% [markdown]
# <div class="">
#     <h3>1. Data Exploration</h3>
# </div>

# %% [markdown]
# The first broad component of your notebook should enable you to familiarise yourselves with the given data, an outline of which is given at the end of this challenge specification.
#
# What is new in this challenge is that you will be working with image data. Therefore, you should have a look at example images located in the *imgs.zip* file (see description below). If you decide to work with the native or the skimage features, make sure to understand them!
#
# Among others, this section should investigate:
#
# - Distribution of the different image dimensions (including the number of channels)
# - Distribution of the different labels that the images are assigned to
#
# The image labels are organized in a taxonomy. We will measure the final model performance for the classification into the *level2* categories. Make sure to understand the meaning of this label inside the taxonomy.

# %% [markdown]
# <div class="">
#     <h3>2. Data Pre-processing</h3>
# </div>

# %% [markdown]
# The previous step should give you a better understanding of which pre-processing is required for the data based on your approach:
#
# - If you decide to work with the provided features, some data cleaning may be required to make full use of all the data.
# - If you decide to extract your own features from the images, you should explain your approach in this section.
# - If you decide to work directly with the images themselves, preprocessing the images may improve your classification results. In particular, if you work with a neural network the following should be of interest to you:
#
#   - Due to the fully-connected layers (that usually come after the convolutional ones), the input needs to have a fixed dimension.
#   - Data augmentation (image rotation, scaling, cropping, etc. of the existing images) can be used to increase the size of the training data set. This may improve performance especially when little data is available for a particular class.
#   - Be aware of the computational cost! It might be worth rescaling the images to a smaller size!
#
#   All of the operations above are usually realized using a dataloader. This means that you do not need to create a modified version of the dataset and save it to disk. Instead, the dataloader processes the data "on the fly" and in-memory before passing it to the network.
#
#     NB: Although aligning image sizes is necessary to train CNNs, this will prevent your classifier from learning about different object sizes as a feature. Additional gains may be achieved when also taking object sizes into account.

# %% [markdown]
# <div class="">
#     <h3>3. Model Selection</h3>
# </div>

# %% [markdown]
# Perhaps the most important segment of this challenge involves the selection of a model that can successfully handle the given data and yield sensible predictions.
# Instead of focusing exclusively on your final chosen model, it is also important to share your thought process in this notebook by additionally describing alternative candidate models.
#
# The choice of your model is closely connected to the way you preprocessed the input data.
#
# Furthermore, there are other factors which may influence your decision:
#
# - What is the model's complexity?
# - Is the model interpretable?
# - Is the model capable of handling different data-types?
# - Does the model return uncertainty estimates along with predictions?

# %% [markdown]
# <div class="">
#     <h3>4. Parameter Optimisation</h3>
# </div>

# %% [markdown]
# Irrespective of your choice, it is highly likely that your model will have one or more (hyper-)parameters that require tuning.
# There are several techniques for carrying out such a procedure, including cross-validation, Bayesian optimisation, and several others.
# As before, an analysis into which parameter tuning technique best suits your model is expected before proceeding with the optimisation of your model.
#
# If you use a neural network, the optimization of hyperparameters (learning rate, weight decay, etc.) can be a very time-consuming process. In this case, your may decide to carry out smaller experiments and to justify your choice on these preliminary tests.

# %% [markdown]
# <div class="">
#     <h3>5. Model Evaluation</h3>
# </div>

# %% [markdown]
# Some form of pre-evaluation will inevitably be required in the preceding sections in order to both select an appropriate model and configure its parameters appropriately.
# In this final section, you may evaluate other aspects of the model such as:
#
# - Assessing the running time of your model;
# - Determining whether some aspects can be parallelised;
# - Training the model with smaller subsets of the data.
# - etc.
#
# For the evaluation of the classification results, you should use the F1 measure (see Submission Instructions). Here the focus should be on level2 classification. A classification evaluation for other labels is optional.
#
# Please note that you are responsible for creating a sensible train/validation/test split. There is no predefined held-out test data.

# %% [markdown]
# <div class="alert alert-danger">
#     <b>N.B.</b> Please note that the items listed under each heading are neither exhaustive, nor are you expected to explore every given suggestion.
#     Nonetheless, these should serve as a guideline for your work in both this and upcoming challenges.
#     As always, you should use your intuition and understanding in order to decide which analysis best suits the assigned task.
# </div>

# %% [markdown]
# <div class="">
#     <h2>Submission Instructions</h2>
#     <hr style="height:1px;border:none;color:#333;background-color:#333;" />
# </div>

# %% [markdown]
# - The goal of this challenge is to construct a model for predicting Plankton (taxonomy level 2) classes.
#
# - Your submission will be the <b>HTML version of your notebook</b> exploring the various modelling aspects described above.
#
# - At the end of the notebook you should indicate your final evaluation score on a held-out test set. As an evaluation metric you should use the F1 score with the *average=macro* option as it is provided by the scikit-learn library. See the following link for more information:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html

# %% [markdown]
# <div class="">
#     <h2>Dataset Description</h2>
#     <hr style="height:1px;border:none;color:#333;background-color:#333;"/>
# </div>

# %% [markdown]
# #### * Location of the Dataset on zoe
# The data for this challenge is located at: `/mnt/datasets/plankton/flowcam`
#
# #### * Hierachical Taxonomy Tree for Labels
#
# Each object is represented by a single image and is identified by a unique integer number. It has a name associated to it which is integrated in a hierarchical taxonomic tree. The identifications are gathered from different projects, classified by different people in different contexts, so they often target different taxonomic levels. For example, let us say we classify items of clothing along the following tree
#
#     top
#         shirt
#             long sleeves
#             short sleeves
#         sweater
#             hooded
#             no hood
#     bottom
#         pants
#             jeans
#             other
#         shorts
#
# In a first project, images are classified to the finest level possible, but it may be the case that, on some pictures, it is impossible to determine whether a sweater has a hood or not, in which case it is simply classified as `sweater`. In the second project, the operator classified tops as `shirt` or `sweater` only, and bottoms to the finest level. In a third project, the operator only separated tops from bottoms. In such a context, the original names in the database cannot be used directly because, for example `sweater` will contain images that are impossible to determine as `hooded` or `no hood` *as well as* `hooded` and `no hood` images that were simply not classified further. If all three classes (`sweater`, `hooded`, and `no hood`) are included in the training set, it will likely confuse the classifier. For this reason, we define different target taxonomic levels:
#
# -   `level1` is the finest taxonomic level possible. In the example above, we would include `hooded` and `no hood` but discard all images in `sweater` to avoid confusion; and proceed in the same manner for other classes.
#
# -   `level2` is a grouping of underlying levels. In the example above, it would include `shirt` (which contains all images in `shirt`, `long sleeves`, and `short sleeves`), `sweater` (which, similarly would include this class and all its children), `pants` (including children), and `shorts`. So typically, `level2` contains more images (less discarding), sorted within fewer classes than `level1`, and may therefore be an easier classification problem.
#
# -   `level3` is an even broader grouping. Here it would be `top` vs `bottom`
#
# -   etc.
#
# In the Plankton Image dataset, the objects will be categorised based on a pre-defined 'level1' and 'level2'. You can opt to work on one of them, but we recommend you to work on `level2` because it is an easier classification problem.
#
# #### * Data Structure
#
#     /mnt/datasets/plankton/flowcam/
#         meta.csv
#         taxo.csv
#         features_native.csv.gz
#         features_skimage.csv.gz
#         imgs.zip
#
# * `meta.csv` contains the index of images and their corresponding labels
# * `taxo.csv` defines the taxonomic tree and its potential groupings at various level. Note that, the information is also available in `meta.csv`. Therefore, the information in `taxo.csv` is probably useless, but at least it gives you a global view about taxonomy tree
# * `features_native.csv.gz` contain the morphological handcrafted features computed by ZooProcess. In fact, ZooProcess generates the region of interests (ROI) around each individual object from a original image of Plankton. In addition, it also computes a set of associated features measured on the object. These features are the ones contained in `features_native.csv.gz`
# * `features_skimage.csv.gz` contains the morphological features recomputed with skimage.measure.regionprops on the ROIs produced by ZooProcess.
# * `imgs.zip` contains a post-processed version of the original images. Images are named by `objid`.jpg
#
# #### * Attributes in meta.csv
#
# The file contains the image identifiers (objid) as well as the labels assigned to the images by human operators. Those are defined with various levels of precision:
#
# * <i>unique_name</i>: raw labels from operators
# * <i>level1</i>: cleaned, most detailed labels
# * <i>level2</i>: regrouped (coarser) labels
# * <i>lineage</i>: full taxonomic lineage of the class
#
# Some labels may be missing (coded ‘NA’) at a given level, meaning that the corresponding objects should be discarded for the classification at this level.
#
# #### * imgs.zip
#
# This zip archive contains an *imgs* folder that contains all the images in .jpg format. Do not extract this folder to disk! Instead you will be loading the images to memory. See the code below for a quick how-to:

# %% [markdown]
# <h4>1. Data Exploration</h4>

# %% [markdown]
# We start first by loading both image data and features.

# %%
# !du -sh /mnt/datasets/plankton/flowcam/meta.csv
# !du -sh /mnt/datasets/plankton/flowcam/taxo.csv
# !du -sh /mnt/datasets/plankton/flowcam/features_native.csv.gz
# !du -sh /mnt/datasets/plankton/flowcam/features_skimage.csv.gz
# !du -sh /mnt/datasets/plan/flowcam/imgs.zip
# Out:
# 33M	/mnt/datasets/plankton/flowcam/meta.csv
# 15K	/mnt/datasets/plankton/flowcam/taxo.csv
# 45M	/mnt/datasets/plankton/flowcam/features_native.csv.gz
# 120M	/mnt/datasets/plankton/flowcam/features_skimage.csv.gz
# du: cannot access '/mnt/datasets/plan/flowcam/imgs.zip': No such file or directory

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import random

import zipfile
from io import BytesIO
from PIL import Image
import PIL
import gzip

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential # to create a cnn model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop,Adam
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical

from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
meta=pd.read_csv("/mnt/datasets/plankton/flowcam/meta.csv")
taxo=pd.read_csv("/mnt/datasets/plankton/flowcam/taxo.csv")

# %%
meta.objid=meta.objid.astype('int')
meta=meta.dropna()

# %%
def extract_zip_to_memory(input_zip):
    '''
    This function extracts t!gunzip /mnt/datasets/plankton/flowcam/features_native.csv.gzhe images stored inside the given zip file.
    It stores the result in a python dictionary.
    
    input_zip (string): path to the zip file
    
    returns (dict): {filename (string): image_file (bytes)}
    '''
    input_zip=zipfile.ZipFile(input_zip)
    return {name: BytesIO(input_zip.read(name)) for name in input_zip.namelist() if name.endswith('.jpg')}


img_files = extract_zip_to_memory("/mnt/datasets/plankton/flowcam/imgs.zip")
#Display an example image 
Image.open(img_files['imgs/32738710.jpg'])

#Load the image as a numpy array:
np_arr = np.array(Image.open(img_files['imgs/32738710.jpg']))

# Be aware that the dictionary will occupy roughly 2GB of computer memory!
# Timgs.zipo free this memory again, run:
# del img_files

# %% [markdown]
# We will be focusing in this notebook on images as we would like to understand more through this work on how to use neural networks on images to extract features.
# We try first to understand what kind of images we have.

# %%
i=0
sub_meta = meta[meta.level2=="feces"][:15]
rows = math.ceil(sub_meta.shape[0]/5)
cols = 5
fig,ax = plt.subplots(rows,cols)
fig.set_figheight(8)
fig.set_figwidth(8)
#Plot a sample of class feces' images
for x in sub_meta.objid:
    img = 'imgs/'+str(x)+'.jpg'
    ax[i//cols][i%cols].imshow(Image.open(img_files[img]))
    ax[i//cols][i%cols].set_title(str(img))  
    ax[i//cols][i%cols].grid("off")
    ax[i//cols][i%cols].axis("off")
    i+=1
plt.show()

# %% [markdown]
# We notice few points after we plot the images for different classes:<br/>
# <ul>
#     <li>All the images are greyscale. So we do not have to worry about channels.</li>
#     <li>All the images don't have the same size so we need to think about aligning the images before extracting features either by doing a detection or resizing the images.</li>
#     <li>All the images don't have the same rotation angles. We can consider to augment our data to have all angles.</li>
#     <li>All the images don't have the same brightness/contrast. </li>
#     <li>No visible trace of noise in the images.
# </ul>

# %%
len(img_files)
# Out:
# 243610

# %%
meta.level2.unique().size
# Out:
# 39

# %%
# Paste the countplot of level2
g = sns.countplot(meta.level2)
g.set_xticklabels(g.get_xticklabels(),rotation=90);
sns.set(rc={'figure.figsize':(6,6)})

# %% [markdown]
# We notice that:<br>
# <ul>
#     <li> We have 39 classes of planktons.</li>
#     <li> These classes are not evenly repartioned acroos the dataset. Therefore we need to think of a way to homogenize the dataset.

# %%
train_meta=meta[['objid','level2']]

# %%
train_meta.head()
# Out:
#       objid         level2
# 0  32756761       detritus
# 1  32759364       detritus
# 2  32758055  Rhizosolenids
# 3  32758988          silks
# 4  32760598          silks

# %% [markdown]
# <h4>2. Data Engineering</h4>

# %% [markdown]
# In order to mae it easier to deal with classes, we use Label Encoding (i.e. we transform classes from strings to integers)

# %%
label_encoder = LabelEncoder()

# %%
train_meta.level2 = label_encoder.fit_transform(train_meta.level2)

# %%
#We create our train and validation sets 
x_train_img_a=train_meta.objid.astype('str')+'.jpg'
y_train_a=train_meta.level2

# %%
x_train_img, x_test_img, y_train, y_test = train_test_split(x_train_img_a,y_train_a, test_size=0.3, random_state=42)

# %%
#we use one hot encoding for labels
y_train = to_categorical(y_train, num_classes = len(y_train.unique()))

# %%
y_train.shape
# Out:
# (167992, 39)

# %% [markdown]
# Like stated previously, we resize all our images to the same size (32,32) for train and test sets.

# %%
#We resize all our images to the same size (32,32)
x_train = np.zeros((y_train.shape[0], 32, 32,1))
i = 0
for _,img in enumerate(x_train_img):
    if(i%10000==0):
        print(i)
    np_arr=np.zeros(( 32, 32,1))
    np_arr[:,:,0] =np.array(Image.open(img_files['imgs/'+img]).resize([32,32],PIL.Image.ANTIALIAS))

    x_train[i]=np_arr
    i+=1
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000

# %%
#Same way we resize test data
x_test = np.zeros((x_test_img.shape[0], 32, 32,1))
i = 0
for _,img in enumerate(x_test_img):
    if(i%10000==0):
        print(i)
    np_arr=np.zeros(( 32, 32,1))
    np_arr[:,:,0] =np.array(Image.open(img_files['imgs/'+img]).resize([32,32],PIL.Image.ANTIALIAS))

    x_test[i]=np_arr
    i+=1
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000

# %% [markdown]
# Now in order to fix the disparity problem, we fix this by generating new images by changing rotation, flip, scale (zoom), shifting and brightness.

# %%
#Plot array of images
def plotImages( images_arr, n_images=5):
    fig, axes = plt.subplots(n_images, n_images, figsize=(5,5))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        if img.ndim != 2:
            img = img.reshape( (32,32))
        ax.imshow( img, cmap="Greys_r")
        ax.set_xticks(())
        ax.set_yticks(())
    plt.tight_layout()

# %%
#Data augmentation
image_gen = ImageDataGenerator(
    rotation_range=360,
    width_shift_range=.15,
    height_shift_range=.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='wrap')

# %%
# %%time
cst = 4000
y_label = pd.DataFrame()
y_label['encoded'] = y_train.argmax(axis=1)
x_pre = np.array([])
y_pre = np.array([])
for c in range(39):
    print("Classe:", c," ",label_encoder.inverse_transform(c))
    count = y_label[y_label.encoded==c].count().item()
    num_img = cst - count
    augmented = np.array([])
    if num_img > 0:
        images  = x_train[np.where(np.argmax(y_train,axis=1)==c)]
        print("Number of added images: ",num_img)
        for i in range(num_img):
            dict_ = image_gen.get_random_transform((32,32))
            im_ = image_gen.apply_transform(images[random.randint(0,len(images)-1)],dict_)
            if augmented.size ==0:
                augmented = np.array([im_])
            else:
                augmented = np.concatenate((augmented,[im_]))
        if x_pre.size ==0:
            x_pre = np.array(augmented)
        else:
            x_pre = np.concatenate((x_pre,augmented))
        a = np.zeros((num_img,39))
        a[:,c] = 1
        if y_pre.size==0:
            y_pre = a
        else:
            y_pre = np.concatenate((y_pre, a),axis=0)
        print("Shape of x_pre: ",x_pre.shape)
        print("Shape of y_pre: ",y_pre.shape)
# Out:
# Classe: 0   Annelida
# Number of added images:  3668
# Shape of x_pre:  (3668, 32, 32, 1)
# Shape of y_pre:  (3668, 39)
# Classe: 1   Asterionellopsis
# Number of added images:  3917
# Shape of x_pre:  (7585, 32, 32, 1)
# Shape of y_pre:  (7585, 39)
# Classe: 2   Bacteriastrum
# Number of added images:  3993
# Shape of x_pre:  (11578, 32, 32, 1)
# Shape of y_pre:  (11578, 39)
# Classe: 3   Ceratocorys horrida
# Number of added images:  3866
# Shape of x_pre:  (15444, 32, 32, 1)
# Shape of y_pre:  (15444, 39)
# Classe: 4   Chaetoceros
# Number of added images:  2511
# Shape of x_pre:  (17955, 32, 32, 1)
# Shape of y_pre:  (17955, 39)
# Classe: 5   Codonaria
# Number of added images:  3412
# Shape of x_pre:  (21367, 32, 32, 1)
# Shape of y_pre:  (21367, 39)
# Classe: 6   Codonellopsis (Dictyocystidae)
# Number of added images:  1991
# Shape of x_pre:  (23358, 32, 32, 1)
# Shape of y_pre:  (23358, 39)
# Classe: 7   Copepoda
# Number of added images:  357
# Shape of x_pre:  (23715, 32, 32, 1)
# Shape of y_pre:  (23715, 39)
# Classe: 8   Coscinodiscids
# Number of added images:  3761
# Shape of x_pre:  (27476, 32, 32, 1)
# Shape of y_pre:  (27476, 39)
# Classe: 9   Cyttarocylis
# Number of added images:  3935
# Shape of x_pre:  (31411, 32, 32, 1)
# Shape of y_pre:  (31411, 39)
# Classe: 10   Dictyocysta
# Number of added images:  3624
# Shape of x_pre:  (35035, 32, 32, 1)
# Shape of y_pre:  (35035, 39)
# Classe: 11   Dinophysiales
# Number of added images:  3634
# Shape of x_pre:  (38669, 32, 32, 1)
# Shape of y_pre:  (38669, 39)
# Classe: 12   Hemiaulus
# Number of added images:  3521
# Shape of x_pre:  (42190, 32, 32, 1)
# Shape of y_pre:  (42190, 39)
# Classe: 13   Lithodesmioides
# Number of added images:  3954
# Shape of x_pre:  (46144, 32, 32, 1)
# Shape of y_pre:  (46144, 39)
# Classe: 14   Neoceratium
# Classe: 15   Odontella (Mediophyceae)
# Number of added images:  3904
# Shape of x_pre:  (50048, 32, 32, 1)
# Shape of y_pre:  (50048, 39)
# Classe: 16   Pleurosigma
# Number of added images:  3872
# Shape of x_pre:  (53920, 32, 32, 1)
# Shape of y_pre:  (53920, 39)
# Classe: 17   Protoperidinium
# Number of added images:  2433
# Shape of x_pre:  (56353, 32, 32, 1)
# Shape of y_pre:  (56353, 39)
# Classe: 18   Retaria
# Number of added images:  3859
# Shape of x_pre:  (60212, 32, 32, 1)
# Shape of y_pre:  (60212, 39)
# Classe: 19   Rhabdonella
# Number of added images:  3750
# Shape of x_pre:  (63962, 32, 32, 1)
# Shape of y_pre:  (63962, 39)
# Classe: 20   Rhizosolenids
# Number of added images:  2715
# Shape of x_pre:  (66677, 32, 32, 1)
# Shape of y_pre:  (66677, 39)
# Classe: 21   Stenosemella
# Number of added images:  3756
# Shape of x_pre:  (70433, 32, 32, 1)
# Shape of y_pre:  (70433, 39)
# Classe: 22   Thalassionema
# Number of added images:  376
# Shape of x_pre:  (70809, 32, 32, 1)
# Shape of y_pre:  (70809, 39)
# Classe: 23   Tintinnidiidae
# Number of added images:  2629
# Shape of x_pre:  (73438, 32, 32, 1)
# Shape of y_pre:  (73438, 39)
# Classe: 24   Undellidae
# Number of added images:  3481
# Shape of x_pre:  (76919, 32, 32, 1)
# Shape of y_pre:  (76919, 39)
# Classe: 25   Xystonellidae
# Number of added images:  3982
# Shape of x_pre:  (80901, 32, 32, 1)
# Shape of y_pre:  (80901, 39)
# Classe: 26   artefact
# Number of added images:  2741
# Shape of x_pre:  (83642, 32, 32, 1)
# Shape of y_pre:  (83642, 39)
# Classe: 27   badfocus (artefact)
# Classe: 28   centric
# Number of added images:  3898
# Shape of x_pre:  (87540, 32, 32, 1)
# Shape of y_pre:  (87540, 39)
# Classe: 29   chainlarge
# Number of added images:  3458
# Shape of x_pre:  (90998, 32, 32, 1)
# Shape of y_pre:  (90998, 39)
# Classe: 30   detritus
# Classe: 31   egg (other)
# Number of added images:  3506
# Shape of x_pre:  (94504, 32, 32, 1)
# Shape of y_pre:  (94504, 39)
# Classe: 32   feces
# Classe: 33   multiple (other)
# Number of added images:  1664
# Shape of x_pre:  (96168, 32, 32, 1)
# Shape of y_pre:  (96168, 39)
# Classe: 34   nauplii (Crustacea)
# Classe: 35   pollen
# Number of added images:  2678
# Shape of x_pre:  (98846, 32, 32, 1)
# Shape of y_pre:  (98846, 39)
# Classe: 36   rods
# Number of added images:  1158
# Shape of x_pre:  (100004, 32, 32, 1)
# Shape of y_pre:  (100004, 39)
# Classe: 37   silks
# Number of added images:  59
# Shape of x_pre:  (100063, 32, 32, 1)
# Shape of y_pre:  (100063, 39)
# Classe: 38   tempChaetoceros danicus
# Number of added images:  3955
# Shape of x_pre:  (104018, 32, 32, 1)
# Shape of y_pre:  (104018, 39)
# CPU times: user 3min 8s, sys: 20.4 s, total: 3min 28s
# Wall time: 3min 28s

# %%
x_train1 = np.concatenate((x_pre,x_train))
y_train1 = np.concatenate((y_pre,y_train))

# %%
plotImages(augmented)

# %%
sns.countplot(np.array(list(filter(lambda x: x not in(32,30,14,27,34) ,np.argmax(y_train1,axis=1)))))
sns.set(rc={'figure.figsize':(15,6)})

# %% [markdown]
# This plot shows the number of total images in the training set. We can see that for all images that used to have less than 4000 we now havethat number of images.

# %% [markdown]
# <h4>3. Builduing a model </h4>
# We now have all the necessary tools to build our classification model. For that we use a common architecture of CNN.

# %%
model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = (5,5), padding = 'Same', activation = 'relu', input_shape = (32,32,1)))
model.add(Conv2D(filters = 16, kernel_size = (5,5), padding = 'Same', activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'Same', activation = 'relu'))
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'Same', activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = 'Same', activation = 'relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3), padding = 'Same', activation = 'relu'))
model.add(MaxPool2D(pool_size = (2,2), strides=(2,2)))
model.add(Dropout(0.25))

# fully connected
model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(y_train.shape[1], activation = "softmax"))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        416
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 16)        6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 39)                10023
# =================================================================
# Total params: 349,591
# Trainable params: 349,079
# Non-trainable params: 512
# _________________________________________________________________

# %%
#Model parameters
optimizer = Adam(lr = 0.001, beta_1 = 0.9, beta_2 = 0.999)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
model.compile(optimizer = optimizer, loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
#Model training
history = model.fit(x_train1, y_train1, epochs=10, batch_size=1000, verbose=1, callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/10
# 272010/272010 [==============================] - 694s 3ms/step - loss: 1.8771 - acc: 0.4586
# Epoch 2/10
# 272010/272010 [==============================] - 626s 2ms/step - loss: 1.3925 - acc: 0.5591
# Epoch 3/10
# 272010/272010 [==============================] - 750s 3ms/step - loss: 1.5943 - acc: 0.5118
# Epoch 4/10
# 272010/272010 [==============================] - 665s 2ms/step - loss: 1.2453 - acc: 0.5989
# Epoch 5/10
# 272010/272010 [==============================] - 592s 2ms/step - loss: 1.1377 - acc: 0.6288
# Epoch 6/10
# 272010/272010 [==============================] - 691s 3ms/step - loss: 1.0651 - acc: 0.6487
# Epoch 7/10
# 272010/272010 [==============================] - 743s 3ms/step - loss: 1.0320 - acc: 0.6597
# Epoch 8/10
# 272010/272010 [==============================] - 747s 3ms/step - loss: 0.9714 - acc: 0.6769
# Epoch 9/10
# 272010/272010 [==============================] - 745s 3ms/step - loss: 0.9274 - acc: 0.6904
# Epoch 10/10
# 272010/272010 [==============================] - 744s 3ms/step - loss: 0.9135 - acc: 0.6944

# %%
#Save the model for easier retrieval
model.save('model1.h5')

# %%
# Plot the loss curve for training
plt.plot(history.history['loss'], color='r', label="Train Loss")
plt.title("Train Loss")
plt.xlabel("Number of Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# Plot the accuracy curve for training
plt.plot(history.history['acc'], color='g', label="Train Accuracy")
plt.title("Train Accuracy")
plt.xlabel("Number of Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# We notice that we reach an accuracy of 70% but that doesn't show us how efective is our model for each class. For that we need to use ROC curves.<br>
# First we use test data to make our predictions.

# %%
predictions = model.predict(np.array(x_test), verbose=1)
# Out:
# 71997/71997 [==============================] - 50s 695us/step

# %%
y_test = to_categorical(y_test, num_classes = 39)

# %% [markdown]
# Then we plot the ROC curves for each class.

# %%
# print(roc_auc_score(y_test,predictions))
pred = label_binarize(np.argmax(predictions,axis=1).reshape(len(predictions),1), classes = range(39))
n_classes = 39
lw = 2
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(label_encoder.inverse_transform(i), roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()
# Out:
# 0.974054352982869

# %% [markdown]
# The ROC plots and the AUC value related to each class show that we only have a handful of good predictors (7 casses only have an AUC grater than 0.8). That's why we can attest that our model overall doesn't perform well.
# We need to train it even more than 10 epochs.

# %%
g = sns.countplot(np.argmax(y_train1,axis=1))
g.set_xticklabels(label_encoder.inverse_transform(range(39)),rotation=90);
sns.set(rc={'figure.figsize':(6,6)})

# %%
print(label_encoder.inverse_transform(predictions.argmax(axis=1)))
print(label_encoder.inverse_transform(y_test.argmax(axis = 1)))
# Out:
# ['detritus' 'detritus' 'detritus' ... 'feces' 'detritus' 'detritus']
# [['Annelida' 'detritus' 'Annelida' ... 'Annelida' 'Annelida' 'Annelida']
#  ['Annelida' 'detritus' 'Annelida' ... 'Annelida' 'Annelida' 'Annelida']
#  ['Annelida' 'Coscinodiscids' 'Annelida' ... 'Annelida' 'Annelida'
#   'Annelida']
#  ...
#  ['Annelida' 'feces' 'Annelida' ... 'Annelida' 'Annelida' 'Annelida']
#  ['Annelida' 'detritus' 'Annelida' ... 'Annelida' 'Annelida' 'Annelida']
#  ['Annelida' 'detritus' 'Annelida' ... 'Annelida' 'Annelida' 'Annelida']]

# %%
score = model.evaluate(x_test, y_test, batch_size=256)
print (score)
# Out:
# 71997/71997 [==============================] - 74s 1ms/step
# [0.7299060464205026, 0.7493367779353762]

# %%
for a,b in zip(model.metrics_names, score):
    print(a,": ",b)
# Out:
# loss :  0.7299060464205026
# acc :  0.7493367779353762

# %% [markdown]
# The accuracy here does not provide enough information here. That is why we used the ROC curves.

# %%
#Load saved data
model=load_model('model1.h5')

# %% [markdown]
# We now train the model for more epochs (first 20 with batch size 1000, then ...)

# %%
history = model.fit(x_train1, y_train1, epochs=20, batch_size=1000, verbose=1, callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/20
# 272010/272010 [==============================] - 531s 2ms/step - loss: 0.8879 - acc: 0.7017
# Epoch 2/20
# 272010/272010 [==============================] - 514s 2ms/step - loss: 0.8894 - acc: 0.7007
# Epoch 3/20
# 272010/272010 [==============================] - 510s 2ms/step - loss: 0.8418 - acc: 0.7161
# Epoch 4/20
# 272010/272010 [==============================] - 512s 2ms/step - loss: 0.8164 - acc: 0.7235
# Epoch 5/20
# 272010/272010 [==============================] - 515s 2ms/step - loss: 0.8187 - acc: 0.7226
# Epoch 6/20
# 272010/272010 [==============================] - 512s 2ms/step - loss: 0.8048 - acc: 0.7269
# Epoch 7/20
# 272010/272010 [==============================] - 518s 2ms/step - loss: 0.7646 - acc: 0.7385
# Epoch 8/20
# 272010/272010 [==============================] - 518s 2ms/step - loss: 0.7844 - acc: 0.7335
# Epoch 9/20
# 272010/272010 [==============================] - 520s 2ms/step - loss: 0.7599 - acc: 0.7403
# Epoch 10/20
# 272010/272010 [==============================] - 540s 2ms/step - loss: 0.7300 - acc: 0.7503
# Epoch 11/20
# 272010/272010 [==============================] - 534s 2ms/step - loss: 0.7188 - acc: 0.7533
# Epoch 12/20
# 272010/272010 [==============================] - 507s 2ms/step - loss: 0.7344 - acc: 0.7486
# Epoch 13/20
# 272010/272010 [==============================] - 520s 2ms/step - loss: 0.7209 - acc: 0.7523
# Epoch 14/20
# 272010/272010 [==============================] - 501s 2ms/step - loss: 0.6973 - acc: 0.7591
# Epoch 15/20
# 272010/272010 [==============================] - 528s 2ms/step - loss: 0.6969 - acc: 0.7596
# Epoch 16/20
# 272010/272010 [==============================] - 528s 2ms/step - loss: 0.7188 - acc: 0.7526
# Epoch 17/20
# 272010/272010 [==============================] - 516s 2ms/step - loss: 0.6707 - acc: 0.7684
# Epoch 18/20
# 272010/272010 [==============================] - 527s 2ms/step - loss: 0.6717 - acc: 0.7674
# Epoch 19/20
# 272010/272010 [==============================] - 548s 2ms/step - loss: 0.6981 - acc: 0.7595
# Epoch 20/20
# 272010/272010 [==============================] - 553s 2ms/step - loss: 0.6695 - acc: 0.7686

# %%
#Save the model for easier retrieval
model.save('model2.h5')

# %%
predictions = model.predict(np.array(x_test), verbose=1)
# Out:
# 71997/71997 [==============================] - 75s 1ms/step

# %%
# print(roc_auc_score(y_test,predictions))
pred = label_binarize(np.argmax(predictions,axis=1).reshape(len(predictions),1), classes = range(39))
n_classes = 39
lw = 2
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(label_encoder.inverse_transform(i), roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# We can see that we improved the distinguishement between classes as the AUC increased for many classes (we now have 17 classes with AUC greater than 0.8 compared to 7 classes for the model with only 10 epochs)

# %%
model=load_model('model1.h5')

# %% [markdown]
# Now we add more epochs and change the batch_size from 1000 to 512 as it requires less time to run.

# %%
history = model.fit(x_train1, y_train1, epochs=10, batch_size=512, verbose=1, callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/10
# 272010/272010 [==============================] - 726s 3ms/step - loss: 0.6473 - acc: 0.7740
# Epoch 2/10
# 272010/272010 [==============================] - 637s 2ms/step - loss: 0.6350 - acc: 0.7788
# Epoch 3/10
# 272010/272010 [==============================] - 476s 2ms/step - loss: 0.6338 - acc: 0.7788
# Epoch 4/10
# 272010/272010 [==============================] - 660s 2ms/step - loss: 0.6264 - acc: 0.7807
# Epoch 5/10
# 272010/272010 [==============================] - 725s 3ms/step - loss: 0.6116 - acc: 0.7849
# Epoch 6/10
# 272010/272010 [==============================] - 725s 3ms/step - loss: 0.6064 - acc: 0.7867
# Epoch 7/10
# 272010/272010 [==============================] - 710s 3ms/step - loss: 0.6015 - acc: 0.7883
# Epoch 8/10
# 272010/272010 [==============================] - 721s 3ms/step - loss: 0.5945 - acc: 0.7905
# Epoch 9/10
# 272010/272010 [==============================] - 722s 3ms/step - loss: 0.5906 - acc: 0.7917
# Epoch 10/10
# 272010/272010 [==============================] - 725s 3ms/step - loss: 0.5927 - acc: 0.7917

# %%
model.save('model3.h5')

# %%
predictions = model.predict(np.array(x_test), verbose=1)
# Out:
# 71997/71997 [==============================] - 68s 941us/step

# %%
# print(roc_auc_score(y_test,predictions))
pred = label_binarize(np.argmax(predictions,axis=1).reshape(len(predictions),1), classes = range(39))
n_classes = 39
lw = 2
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(label_encoder.inverse_transform(i), roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# We notice that we keep improving the AUC for the same classes as previous, while keeping some stable and the rest keep getting worse

# %%
model=load_model('model3.h5')

# %%
history = model.fit(x_train1, y_train1, epochs=10, batch_size=512, verbose=1, callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/10
# 272010/272010 [==============================] - 710s 3ms/step - loss: 0.6279 - acc: 0.7811
# Epoch 2/10
# 272010/272010 [==============================] - 702s 3ms/step - loss: 0.6086 - acc: 0.7858
# Epoch 3/10
# 272010/272010 [==============================] - 734s 3ms/step - loss: 0.6006 - acc: 0.7893
# Epoch 4/10
# 272010/272010 [==============================] - 722s 3ms/step - loss: 0.5915 - acc: 0.7921
# Epoch 5/10
# 272010/272010 [==============================] - 708s 3ms/step - loss: 0.5848 - acc: 0.7942
# Epoch 6/10
# 272010/272010 [==============================] - 725s 3ms/step - loss: 0.5800 - acc: 0.7949
# Epoch 7/10
# 272010/272010 [==============================] - 523s 2ms/step - loss: 0.5742 - acc: 0.7970
# Epoch 8/10
# 272010/272010 [==============================] - 480s 2ms/step - loss: 0.5674 - acc: 0.7993
# Epoch 9/10
# 272010/272010 [==============================] - 479s 2ms/step - loss: 0.5637 - acc: 0.8007
# Epoch 10/10
# 272010/272010 [==============================] - 480s 2ms/step - loss: 0.5608 - acc: 0.8014

# %%
model.save('model3.h5')

# %%
predictions = model.predict(np.array(x_test), verbose=1)
# Out:
# 71997/71997 [==============================] - 36s 497us/step

# %%
# print(roc_auc_score(y_test,predictions))
pred = label_binarize(np.argmax(predictions,axis=1).reshape(len(predictions),1), classes = range(39))
n_classes = 39
lw = 2
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
# Plot all ROC curves
plt.figure()
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(label_encoder.inverse_transform(i), roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Some extension of Receiver operating characteristic to multi-class')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# <h4>Summary</h4>

# %% [markdown]
# We have done the same work as previously for the dataset without augmentation. And we plotted the ROC curves.<br>
# <div>
#     <div>
#             <img src="Capture.PNG" >
#     </div>
# </div>

# %% [markdown]
# <br>
# 1) We noticed that there is improvement in our model (with data auugmentation) especially for classes that used to have small number of images but for classes that have the same or a little more images
# <ul>
#     <li>old model-->new model with data generation</li>
#     <li>Annelida 0.67 --> 0.74 </li>
#     <li>Bacteriastrum 0.7-->0.9</li>
#     <li>Chaaetoceros 0.78-->0.84</li>
#     <li>tempChaetoceros danicus 0.5 --> 0.66 </li>
#     <li>Asterionellopsis 0.5 --> 0.81 </li>
#
#
# </ul>
# 2) We either keep the same AUC value or it decreases
# <ul>
#     <li>Detritus 0.82 -->0.82 </li>
#     <li>Neocerafium 0.95-->0.93</li>
#     <li>nauplii (Crustacea) 0.89-->0.89</li>
# </ul>
# <br>
# 3) However some classes AUC becomes worse with data augmentation
# <ul>
#     <li>Codonaria 0.88--> 0.76</li>
#     <li>Dinophysiales 0.63-->0.59</li>
#     <li>Protoperidenium 0.89-->0.80</li>
#     <li>Rhabdonella 0.72-->0.65</li>
# </ul>
# <br>
# Therefore for future enhancement we can keep the training with the actual image set without data augmentation for some classes where it seems that adding images performs poorly and add them for others where there is a noticrable enhancement.
# For the rest where there is no change between adding data or not we can keep the image set without change
